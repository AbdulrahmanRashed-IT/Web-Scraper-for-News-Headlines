# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.bbc.com/news"

try:

    response = requests.get(url)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, "html.parser")


    headlines = soup.find_all(["h2", "h3"])


    titles = [h.get_text(strip=True) for h in headlines if h.get_text(strip=True)]


    with open("headlines.txt", "w", encoding="utf-8") as file:
        for t in titles:
            file.write(t + "\n")

    print(f" Scraping completed! {len(titles)} headlines saved to 'headlines.txt'.")

except requests.exceptions.RequestException as e:
    print(f" Error fetching the page: {e}")
# Out:
#  Scraping completed! 61 headlines saved to 'headlines.txt'.

# %%
# !cat headlines.txt
# Out:
# Trump says Putin talks 'don't go anywhere' as he imposes new sanctions
# Rubio warns against West Bank annexation after Israel's parliament advances move
# King Charles meets Pope for first time ahead of praying together in Sistine Chapel
# US kills three in second strike on alleged drug boats in the Pacific
# An ex-first lady, a tycoon and a 'safe pair of hands' vie for power in a cocoa superpower
# Rubio warns against West Bank annexation after Israel's parliament advances move
# France backing away from pledge to intercept migrant boats, sources tell BBC
# Myanmar's army is taking back territory with relentless air strikes - and China's help
# Videos show blast at Russia munitions factory that reportedly killed 10
# King Charles meets Pope for first time ahead of praying together in Sistine Chapel
# EU set to endorse deal to turn frozen Russian assets into support for Ukraine
# Blackouts hit Russia's Belgorod as Ukrainian drone attacks surge
# Australia MP names person of interest in Cheryl Grimmer disappearance case
# Forty migrants, including infants, die as boat sinks off Tunisia
# Watch: Millions of red crabs begin annual migration on Christmas Island
# More to explore
# Gen Z rising? Why young Indians aren't taking to the streets
# Toxic air is back again in Delhi - here's why it's so hard to stop it
# What's at stake as Trump boat strikes strain US-Colombia alliance
# Agatha Christie meets Mr Men in new children's books
# Kane can't stop scoring - is the Ballon d'Or within reach?
# Toxic air is back again in Delhi - here's why it's so hard to stop it
# Kane can't stop scoring - is the Ballon d'Or within reach?
# Also in news
# TikTok creator and US marshal shot during LA immigration raid
# US axes website for reporting human rights abuses by US-armed foreign forces
# Tesla profits slide despite record revenue
# Three officers hurt and 24 arrested during disorder in Dublin
# Temu agrees to remove rip-off greeting cards from its site more quickly
# US axes website for reporting human rights abuses by US-armed foreign forces
# British man drowns in Australia after surfboard snaps in wild weather
# Barbs fly as Mamdani and Cuomo meet in final, furious New York mayoral debate
# Tesla profits slide despite record revenue
# Most watched
# Watch: Millions of red crabs begin annual migration on Christmas Island
# Watch: Weather forecast as Storm Benjamin hits England and Wales
# Watch: Mum helps evacuate 22 schoolchildren from bus as it catches fire
# NYC mayoral candidates clash over Trump and political experience
# Trump to Australian ambassador: 'I don't like you either'
# Most read
# Trump says Putin talks 'don't go anywhere' as he imposes new sanctions
# Rubio warns against West Bank annexation after Israel's parliament advances move
# France backing away from pledge to intercept migrant boats, sources tell BBC
# Why Beyond Meat shares surged over 1,000% in four days
# Person of interest in British girl's disappearance named in Australian state parliament
# Weather warnings reduced as Storm Benjamin moves east
# What's the significance of US sanctions on Russian oil?
# TikTok creator and US marshal shot during LA immigration raid
# British man drowns in Australia after surfboard snaps in wild weather
# Myanmar's army is taking back territory with relentless air strikes - and China's help
# Sport
# Kane can't stop scoring - is the Ballon d'Or within reach?
# A glimpse of the future? Liverpool 'near perfect' despite Isak injury
# I nearly quit football for basketball - Gvardiol
# Women's World Cup: India make solid start v New Zealand in crucial game
# Women's Footballer of the Year contender Hampton
# A glimpse of the future? Liverpool 'near perfect' despite Isak injury
# England win series v NZ after rain ruins third T20
# Wembanyama stars as Spurs dominate Mavericks
# I nearly quit football for basketball - Gvardiol
# Sign up to News Briefing

# %%
from google.colab import files
files.download("headlines.txt")
